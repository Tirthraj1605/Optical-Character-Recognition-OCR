# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# Out:
# Requirement already satisfied: pytesseract in c:\users\tirthraj bhalodiya\appdata\local\programs\python\python310\lib\site-packages (0.3.10)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: packaging>=21.3 in c:\users\tirthraj bhalodiya\appdata\local\programs\python\python310\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\tirthraj bhalodiya\appdata\local\programs\python\python310\lib\site-packages (from pytesseract) (10.0.0)
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import cv2 
import pytesseract
import matplotlib.pyplot as plt
from IPython.display import Image
from pylab import rcParams
import numpy as np
from pprint import pprint
from pytesseract import Output

# %%
rcParams['figure.figsize'] = 8, 16

# %%
file_name = "Image2.JPEG"

# %%
img = cv2.imread(file_name)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
text_out = pytesseract.image_to_string(img)

# %%
text_out
# Out:
# ''

# %%
dir(pytesseract)
# Out:
# ['ALTONotSupported',
#  'Output',
#  'TSVNotSupported',
#  'TesseractError',
#  'TesseractNotFoundError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'get_languages',
#  'get_tesseract_version',
#  'image_to_alto_xml',
#  'image_to_boxes',
#  'image_to_data',
#  'image_to_osd',
#  'image_to_pdf_or_hocr',
#  'image_to_string',
#  'pytesseract',
#  'run_and_get_output']

# %%
d = pytesseract.image_to_data(img, output_type=Output.DICT)

# %%
d.keys()
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %%
d["text"]
# Out:
# ['', '', '', '', '']
